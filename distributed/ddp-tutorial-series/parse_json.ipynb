# %%
import pandas as pd
import json

# %%
with open('./log/train_singlegpu/nomster_228293.1683906339674.pt.trace.json',"r") as f:
    json_trace = json.load(f)

# %%
df = pd.DataFrame.from_records(json_trace['traceEvents'])

# %% [markdown]
# Iteration Start: PyTorch Profiler "ts": 1683906339662854

# %%
df[df['name']=='[memory]']
# Out:
#     ph                cat      name     pid     tid                ts  dur  \
# 41   i  cpu_instant_event  [memory]  228293  228312  1683906339664045  NaN
# 42   i  cpu_instant_event  [memory]  228293  228312  1683906339664060  NaN
# 43   i  cpu_instant_event  [memory]  228293  228312  1683906339664081  NaN
# 44   i  cpu_instant_event  [memory]  228293  228312  1683906339664098  NaN
# 45   i  cpu_instant_event  [memory]  228293  228312  1683906339664110  NaN
# 46   i  cpu_instant_event  [memory]  228293  228312  1683906339664145  NaN
# 47   i  cpu_instant_event  [memory]  228293  228312  1683906339664160  NaN
# 48   i  cpu_instant_event  [memory]  228293  228312  1683906339664178  NaN
# 49   i  cpu_instant_event  [memory]  228293  228312  1683906339664191  NaN
# 50   i  cpu_instant_event  [memory]  228293  228312  1683906339664192  NaN
# 51   i  cpu_instant_event  [memory]  228293  228312  1683906339664213  NaN
# ...
